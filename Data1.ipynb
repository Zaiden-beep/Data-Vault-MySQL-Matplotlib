# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use ('ggplot')
import numpy as np
import mysql.connector


mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  passwd="Zaidn94",
  database="My_Products_Databse")
  
cursor = mydb.cursor()

sql = "SELECT * FROM my_products_databse.`my_products_databse - sheet1`;"

cursor.execute(sql)
myresult = cursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (0, 'Simba', 'Coke', 'Cadbury', 'pepper Steak', 'Pear', 'Vanilla', 'Spinach')
# (1, 'Lays', 'Fanta', 'Tex', 'Chicken', 'Apple', 'Chocolate', 'Cabbage')

# %%
import matplotlib.pyplot as plt
import mysql.connector
import numpy as np




mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  passwd="Zaidn94",
  database="My_Products_Databse")
  
cursor = mydb.cursor()
cursor.execute(sql)

plt.bar([1,3,5,7,9],[5,2,7,8,2], label="Quatity")

plt.bar([2,4,6,8,10],[8,6,2,5,6], label="Products", color='g')
plt.legend()
plt.title('STORE DATA OF PRODUCT & BRANDS')
plt.ylabel('Quatity')
plt.xlabel('Products')

plt.show()
